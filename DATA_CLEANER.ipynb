# %%
variables = [
    # Identifiers and demographics
    "ANONID", "GENDER", "YRBIRTH",
    "AGE2008", "AGE2013", "AGE2018",
    "WAVE2008", "WAVE2013", "WAVE2018",
    "VOIVOD2008", "VOIVOD2013", "VOIVOD2018",
    "SIZE2008", "SIZE2013", "SIZE2018",
    "EDUC2008", "EDUC2013", "EDUC2018",
    "JOB2008_SCALE3", "JOB2013_SCALE3", "JOB2018_SCALE3",
    "VR22", "UK21", "TK21",
    "VR01", "UK01", "TK01",
    "VM01", "UB04", "TD01",
    "VW05", "UM05", "TM31",

    # NHP 2008 (38 items)
    "VZ02A01", "VZ02A02", "VZ02A03", "VZ02A04", "VZ02A05",
    "VZ02A06", "VZ02A07", "VZ02A08", "VZ02A09", "VZ02A10",
    "VZ02A11", "VZ02A12", "VZ02A13", "VZ02A14", "VZ02A15",
    "VZ02A16", "VZ02A17", "VZ02A18", "VZ02A19", "VZ02A20",
    "VZ02A21", "VZ02A22", "VZ02A23", "VZ02A24", "VZ02A25",
    "VZ02A26", "VZ02A27", "VZ02A28", "VZ02A29", "VZ02A30",
    "VZ02A31", "VZ02A32", "VZ02A33", "VZ02A34", "VZ02A35",
    "VZ02A36", "VZ02A37", "VZ02A38",

    # NHP 2013 (38 items)
    "UR01A_01", "UR01A_02", "UR01A_03", "UR01A_04", "UR01A_05",
    "UR01A_06", "UR01A_07", "UR01A_08", "UR01A_09", "UR01A_10",
    "UR01A_11", "UR01A_12", "UR01A_13", "UR01A_14", "UR01A_15",
    "UR01A_16", "UR01A_17", "UR01A_18", "UR01A_19", "UR01A_20",
    "UR01A_21", "UR01A_22", "UR01A_23", "UR01A_24", "UR01A_25",
    "UR01A_26", "UR01A_27", "UR01A_28", "UR01A_29", "UR01A_30",
    "UR01A_31", "UR01A_32", "UR01A_33", "UR01A_34", "UR01A_35",
    "UR01A_36", "UR01A_37", "UR01A_38",

    # NHP 2018 (38 items)
    "TP09A_01", "TP09A_02", "TP09A_03", "TP09A_04", "TP09A_05",
    "TP09A_06", "TP09A_07", "TP09A_08", "TP09A_09", "TP09A_10",
    "TP09A_11", "TP09A_12", "TP09A_13", "TP09A_14", "TP09A_15",
    "TP09A_16", "TP09A_17", "TP09A_18", "TP09A_19", "TP09A_20",
    "TP09A_21", "TP09A_22", "TP09A_23", "TP09A_24", "TP09A_25",
    "TP09A_26", "TP09A_27", "TP09A_28", "TP09A_29", "TP09A_30",
    "TP09A_31", "TP09A_32", "TP09A_33", "TP09A_34", "TP09A_35",
    "TP09A_36", "TP09A_37", "TP09A_38"]

# %%
import pandas as pd

df = pd.read_csv("/Users/lukadecaters/Desktop/R_Project-Reproducible-Research/Polpan1988_2018.csv")

df[variables].to_csv("/Users/lukadecaters/Desktop/R_Project-Reproducible-Research/cleaned_data3.csv", index=False)
# Out:
# /var/folders/m9/k5l8vc6s6h94chj2w04z67kc0000gn/T/ipykernel_24608/87005043.py:3: DtypeWarning: Columns (4848,4912,4935,4955,4984,5078,5081,5261,5319,5348,5377) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("/Users/lukadecaters/Desktop/R_Project-Reproducible-Research/Polpan1988_2018.csv")
